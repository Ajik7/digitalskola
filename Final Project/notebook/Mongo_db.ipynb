# %%
import pymongo
import pandas as pd
import sqlalchemy

client = pymongo.MongoClient("mongodb+srv://dbajikurniawan:dbajikurniawan@cluster0.xvsguzc.mongodb.net/test")
# Database Name
db = client["sample_training"]
 
# Collection Name
col_zips = db["zips"]
col_comp = db["companies"]

#collection to dataframe
df_zips = pd.DataFrame(list(col_zips.find()))
df_com = pd.DataFrame(list(col_comp.find()))

# %%
#set column loc and office to list
df_zip = pd.DataFrame(df_zips['loc'].values.tolist())
df_office = pd.DataFrame(df_com['offices'].values.tolist())

# %%
#data office
df_office[0]
# Out:
# 0       {'description': '', 'address1': '710 - 2nd Ave...
# 1       {'description': '', 'address1': 'Suite 200', '...
# 2       {'description': None, 'address1': '', 'address...
# 3       {'description': 'Headquarters', 'address1': '1...
# 4       {'description': '', 'address1': '1355 Market S...
#                               ...
# 9495                                                 None
# 9496    {'description': '', 'address1': '', 'address2'...
# 9497                                                 None
# 9498    {'description': 'Corporate Headquarters', 'add...
# 9499                                                 None
# Name: 0, Length: 9500, dtype: object

# %%
df_off = df_office.assign(new=df_office[0])
df_off
# Out:
#                                                       0  \
# 0     {'description': '', 'address1': '710 - 2nd Ave...
# 1     {'description': '', 'address1': 'Suite 200', '...
# 2     {'description': None, 'address1': '', 'address...
# 3     {'description': 'Headquarters', 'address1': '1...
# 4     {'description': '', 'address1': '1355 Market S...
# ...                                                 ...
# 9495                                               None
# 9496  {'description': '', 'address1': '', 'address2'...
# 9497                                               None
# 9498  {'description': 'Corporate Headquarters', 'add...
# 9499                                               None
#
#                                                       1  \
# 0     {'description': '', 'address1': '270 Lafayette...
# 1                                                  None
# 2                                                  None
# 3     {'description': 'Europe HQ', 'address1': '', '...
# 4                                                  None
# ...                                                 ...
# 9495                                               None
# 9496                                               None
# 9497                                               None
# 9498                                               None
# 9499                                               None
#
#                                                       2     3     4     5  \
# 0                                                  None  None  None  None
# 1                                                  None  None  None  None
# 2                                                  None  None  None  None
# 3     {'description': 'New York', 'address1': '340 M...  None  None  None
# 4                                                  None  None  None  None
# ...                                                 ...   ...   ...   ...
# 9495                                               None  None  None  None
# 9496                                               None  None  None  None
# 9497                                               None  None  None  None
# 9498                                               None  None  None  None
# 9499                                               None  None  None  None
#
#          6     7     8     9  ...    16    17    18    19    20    21    22  \
# 0     None  None  None  None  ...  None  None  None  None  None  None  None
# 1     None  None  None  None  ...  None  None  None  None  None  None  None
# 2     None  None  None  None  ...  None  None  None  None  None  None  None
# 3     None  None  None  None  ...  None  None  None  None  None  None  None
# 4     None  None  None  None  ...  None  None  None  None  None  None  None
# ...    ...   ...   ...   ...  ...   ...   ...   ...   ...   ...   ...   ...
# 9495  None  None  None  None  ...  None  None  None  None  None  None  None
# 9496  None  None  None  None  ...  None  None  None  None  None  None  None
# 9497  None  None  None  None  ...  None  None  None  None  None  None  None
# 9498  None  None  None  None  ...  None  None  None  None  None  None  None
# 9499  None  None  None  None  ...  None  None  None  None  None  None  None
#
#         23    24                                                new
# 0     None  None  {'description': '', 'address1': '710 - 2nd Ave...
# 1     None  None  {'description': '', 'address1': 'Suite 200', '...
# 2     None  None  {'description': None, 'address1': '', 'address...
# 3     None  None  {'description': 'Headquarters', 'address1': '1...
# 4     None  None  {'description': '', 'address1': '1355 Market S...
# ...    ...   ...                                                ...
# 9495  None  None                                               None
# 9496  None  None  {'description': '', 'address1': '', 'address2'...
# 9497  None  None                                               None
# 9498  None  None  {'description': 'Corporate Headquarters', 'add...
# 9499  None  None                                               None
#
# [9500 rows x 26 columns]

# %%
df_off["new"]
# Out:
# 0       {'description': '', 'address1': '710 - 2nd Ave...
# 1       {'description': '', 'address1': 'Suite 200', '...
# 2       {'description': None, 'address1': '', 'address...
# 3       {'description': 'Headquarters', 'address1': '1...
# 4       {'description': '', 'address1': '1355 Market S...
#                               ...
# 9495                                                 None
# 9496    {'description': '', 'address1': '', 'address2'...
# 9497                                                 None
# 9498    {'description': 'Corporate Headquarters', 'add...
# 9499                                                 None
# Name: new, Length: 9500, dtype: object

# %%
df_off1=df_off["new"]

# %%
d = df_off1

# %%
d["D"]= pd.Series(d)
d["D"]
# Out:
# 0       {'description': '', 'address1': '710 - 2nd Ave...
# 1       {'description': '', 'address1': 'Suite 200', '...
# 2       {'description': None, 'address1': '', 'address...
# 3       {'description': 'Headquarters', 'address1': '1...
# 4       {'description': '', 'address1': '1355 Market S...
#                               ...
# 9495                                                 None
# 9496    {'description': '', 'address1': '', 'address2'...
# 9497                                                 None
# 9498    {'description': 'Corporate Headquarters', 'add...
# 9499                                                 None
# Name: new, Length: 9500, dtype: object

# %%
df_companies = d["D"].dropna()

# %%
df_companies
# Out:
# 0       {'description': '', 'address1': '710 - 2nd Ave...
# 1       {'description': '', 'address1': 'Suite 200', '...
# 2       {'description': None, 'address1': '', 'address...
# 3       {'description': 'Headquarters', 'address1': '1...
# 4       {'description': '', 'address1': '1355 Market S...
#                               ...
# 9492    {'description': '', 'address1': '32 Crosby Dri...
# 9493    {'description': 'HQ', 'address1': 'HylsvÃ¤gen ...
# 9494    {'description': 'Corporate Headquarters', 'add...
# 9496    {'description': '', 'address1': '', 'address2'...
# 9498    {'description': 'Corporate Headquarters', 'add...
# Name: new, Length: 6916, dtype: object

# %%
df_companies= pd.DataFrame(df_companies.values.tolist())
df_companies
# Out:
#                  description                   address1         address2  \
# 0                                      710 - 2nd Avenue       Suite 1100
# 1                                             Suite 200  654 High Street
# 2                       None
# 3               Headquarters           1601 Willow Road
# 4                                       1355 Market St.
# ...                      ...                        ...              ...
# 6911                                    32 Crosby Drive
# 6912                      HQ               HylsvÃ¤gen 4
# 6913  Corporate Headquarters        3100 Coronado Drive
# 6914
# 6915  Corporate Headquarters  2 Waters Park Drive, #250
#
#      zip_code           city state_code country_code   latitude   longitude
# 0       98104        Seattle         WA          USA  47.603122 -122.333253
# 1       94301      Palo Alto         CA          ISR        NaN         NaN
# 2                                    CA          USA  37.269175 -119.306607
# 3       94025     Menlo Park         CA          USA  37.416050 -122.151801
# 4       94103  San Francisco         CA          USA  37.776805 -122.416924
# ...       ...            ...        ...          ...        ...         ...
# 6911    01730        Bedford         MA          USA  42.509865  -71.247192
# 6912    72130     VÃ¤sterÃ¥s       None          SWE  59.617364   16.559539
# 6913    95054    Santa Clara         CA          USA  37.377798 -121.974454
# 6914               Sunnyvale         CA          USA  37.369195 -122.036849
# 6915    94403      San Mateo         CA          USA  37.553121 -122.301534
#
# [6916 rows x 9 columns]

# %%
df_merged_companies= df_com.join(df_companies, lsuffix='_left', rsuffix='_right')
df_merged_companies
# Out:
#                            _id                   name              permalink  \
# 0     52cdef7c4bab8bd675297d8a               Wetpaint                   abc2
# 1     52cdef7c4bab8bd675297d8f              Omnidrive              omnidrive
# 2     52cdef7c4bab8bd675297d9e                    CBS                    cbs
# 3     52cdef7c4bab8bd675297d8e               Facebook               facebook
# 4     52cdef7c4bab8bd675297d94                Twitter                twitter
# ...                        ...                    ...                    ...
# 9495  52cdef7f4bab8bd67529c6bd  AffittiVacanze-Spagna  affittivacanze-spagna
# 9496  52cdef7f4bab8bd67529c6d6               InstantQ               instantq
# 9497  52cdef7f4bab8bd67529c6d7           Kicker Films           kicker-films
# 9498  52cdef7f4bab8bd67529c6d8               NextLabs               nextlabs
# 9499  52cdef7f4bab8bd67529c6f8            goBookmaker            gobookmaker
#
#                                          crunchbase_url  \
# 0            http://www.crunchbase.com/company/wetpaint
# 1           http://www.crunchbase.com/company/omnidrive
# 2                 http://www.crunchbase.com/company/cbs
# 3            http://www.crunchbase.com/company/facebook
# 4             http://www.crunchbase.com/company/twitter
# ...                                                 ...
# 9495  http://www.crunchbase.com/company/affittivacan...
# 9496         http://www.crunchbase.com/company/instantq
# 9497     http://www.crunchbase.com/company/kicker-films
# 9498         http://www.crunchbase.com/company/nextlabs
# 9499      http://www.crunchbase.com/company/gobookmaker
#
#                              homepage_url                       blog_url  \
# 0                 http://wetpaint-inc.com    http://digitalquarters.net/
# 1                http://www.omnidrive.com  http://www.omnidrive.com/blog
# 2
# 3                     http://facebook.com       http://blog.facebook.com
# 4                      http://twitter.com        http://twitter.com/blog
# ...                                   ...                            ...
# 9495  http://www.affittivacanze-spagna.it
# 9496              http://www.instantq.com       http://blog.instantq.com
# 9497           http://www.kickerfilms.com
# 9498              http://www.nextlabs.com  http://nextlabs.wordpress.com
# 9499           http://www.gobookmaker.com    http://blog.gobookmaker.com
#
#                                 blog_feed_url twitter_username  \
# 0            http://digitalquarters.net/feed/  BachelrWetpaint
# 1       http://feeds.feedburner.com/omnidrive         Nomadesk
# 2
# 3           http://blog.facebook.com/atom.php         facebook
# 4     http://feeds.feedburner.com/TwitterBlog          twitter
# ...                                       ...              ...
# 9495
# 9496                                                  instantq
# 9497                                              Kicker_Films
# 9498                                                  nextlabs
# 9499                                               gobookmaker
#
#         category_code  number_of_employees  ...  \
# 0                 web                 47.0  ...
# 1     network_hosting                  NaN  ...
# 2                news                  NaN  ...
# 3              social               5299.0  ...
# 4              social               1300.0  ...
# ...               ...                  ...  ...
# 9495              web                  NaN  ...
# 9496      advertising                  3.0  ...
# 9497        ecommerce                  1.0  ...
# 9498       enterprise                100.0  ...
# 9499              web                  NaN  ...
#
#                                                     ipo  description_right  \
# 0                                                   NaN
# 1                                                  None
# 2     {'valuation_amount': None, 'valuation_currency...               None
# 3     {'valuation_amount': 104000000000, 'valuation_...       Headquarters
# 4     {'valuation_amount': 18100000000, 'valuation_c...
# ...                                                 ...                ...
# 9495                                               None                NaN
# 9496                                               None                NaN
# 9497                                               None                NaN
# 9498                                               None                NaN
# 9499                                               None                NaN
#
#               address1         address2 zip_code           city state_code  \
# 0     710 - 2nd Avenue       Suite 1100    98104        Seattle         WA
# 1            Suite 200  654 High Street    94301      Palo Alto         CA
# 2                                                                       CA
# 3     1601 Willow Road                     94025     Menlo Park         CA
# 4      1355 Market St.                     94103  San Francisco         CA
# ...                ...              ...      ...            ...        ...
# 9495               NaN              NaN      NaN            NaN        NaN
# 9496               NaN              NaN      NaN            NaN        NaN
# 9497               NaN              NaN      NaN            NaN        NaN
# 9498               NaN              NaN      NaN            NaN        NaN
# 9499               NaN              NaN      NaN            NaN        NaN
#
#      country_code   latitude   longitude
# 0             USA  47.603122 -122.333253
# 1             ISR        NaN         NaN
# 2             USA  37.269175 -119.306607
# 3             USA  37.416050 -122.151801
# 4             USA  37.776805 -122.416924
# ...           ...        ...         ...
# 9495          NaN        NaN         NaN
# 9496          NaN        NaN         NaN
# 9497          NaN        NaN         NaN
# 9498          NaN        NaN         NaN
# 9499          NaN        NaN         NaN
#
# [9500 rows x 51 columns]

# %%
#kolom yang akan direname
description
address1
address2
zip_code
city
state_code
country_code
latitude
longitude

# %%
#tipe data yang didrop(object)
image
products
relationships
competitions
providerships
funding_rounds
investments
acquisitions
offices
milestones
video_embeds
screenshots
external_links
partners

# %%
data_companies=df_merged_companies.rename(columns = {0: 'description', 1: 'address1', 2: 'address2', 3: 'zip_code', 4: 'city', 5: 'state_code', 6: 'country_code', 7: 'latitude', 8: 'longitude'})

# %%
data_companies= data_companies.drop(['image','products','relationships','competitions','providerships','funding_rounds','investments','acquisition','acquisitions','offices','milestones','video_embeds','screenshots','external_links','partners', 'ipo'], axis = 1)

# %%
data_companies.head()
# Out:
#                         _id       name  permalink  \
# 0  52cdef7c4bab8bd675297d8a   Wetpaint       abc2
# 1  52cdef7c4bab8bd675297d8f  Omnidrive  omnidrive
# 2  52cdef7c4bab8bd675297d9e        CBS        cbs
# 3  52cdef7c4bab8bd675297d8e   Facebook   facebook
# 4  52cdef7c4bab8bd675297d94    Twitter    twitter
#
#                                 crunchbase_url              homepage_url  \
# 0   http://www.crunchbase.com/company/wetpaint   http://wetpaint-inc.com
# 1  http://www.crunchbase.com/company/omnidrive  http://www.omnidrive.com
# 2        http://www.crunchbase.com/company/cbs
# 3   http://www.crunchbase.com/company/facebook       http://facebook.com
# 4    http://www.crunchbase.com/company/twitter        http://twitter.com
#
#                         blog_url                            blog_feed_url  \
# 0    http://digitalquarters.net/         http://digitalquarters.net/feed/
# 1  http://www.omnidrive.com/blog    http://feeds.feedburner.com/omnidrive
# 2
# 3       http://blog.facebook.com        http://blog.facebook.com/atom.php
# 4        http://twitter.com/blog  http://feeds.feedburner.com/TwitterBlog
#
#   twitter_username    category_code  number_of_employees  ...  deadpooled_url  \
# 0  BachelrWetpaint              web                 47.0  ...             NaN
# 1         Nomadesk  network_hosting                  NaN  ...
# 2                              news                  NaN  ...            None
# 3         facebook           social               5299.0  ...
# 4          twitter           social               1300.0  ...
#
#    description_right          address1         address2 zip_code  \
# 0                     710 - 2nd Avenue       Suite 1100    98104
# 1                            Suite 200  654 High Street    94301
# 2               None
# 3       Headquarters  1601 Willow Road                     94025
# 4                      1355 Market St.                     94103
#
#             city state_code country_code   latitude   longitude
# 0        Seattle         WA          USA  47.603122 -122.333253
# 1      Palo Alto         CA          ISR        NaN         NaN
# 2                        CA          USA  37.269175 -119.306607
# 3     Menlo Park         CA          USA  37.416050 -122.151801
# 4  San Francisco         CA          USA  37.776805 -122.416924
#
# [5 rows x 35 columns]

# %%
#collection Zips
df_zip
# Out:
#                y           x
# 0      33.414625   86.999607
# 1      33.434277   87.167455
# 2      34.082117   87.048395
# 3      33.176964   86.616145
# 4      33.633560   86.948221
# ...          ...         ...
# 29465  43.771201  110.857493
# 29466  42.932336  110.955560
# 29467  42.917629  110.133624
# 29468  42.247340  110.210865
# 29469  42.933026  111.011354
#
# [29470 rows x 2 columns]

# %%
df=df_zip.rename(columns = {'y': 'latitude', 'x': 'longitude'})
df
# Out:
#         latitude   longitude
# 0      33.414625   86.999607
# 1      33.434277   87.167455
# 2      34.082117   87.048395
# 3      33.176964   86.616145
# 4      33.633560   86.948221
# ...          ...         ...
# 29465  43.771201  110.857493
# 29466  42.932336  110.955560
# 29467  42.917629  110.133624
# 29468  42.247340  110.210865
# 29469  42.933026  111.011354
#
# [29470 rows x 2 columns]

# %%
df_merged = df_zips.join(df)
df_merged
# Out:
#                             _id        city    zip  \
# 0      5c8eccc1caa187d17ca6ed1a    HUEYTOWN  35023
# 1      5c8eccc1caa187d17ca6ed1e       ADGER  35006
# 2      5c8eccc1caa187d17ca6ed2a  CRANE HILL  35053
# 3      5c8eccc1caa187d17ca6ed2d  COLUMBIANA  35051
# 4      5c8eccc1caa187d17ca6ed32       ALDEN  35073
# ...                         ...         ...    ...
# 29465  5c8eccc1caa187d17ca7603e       MOOSE  83012
# 29466  5c8eccc1caa187d17ca76043     BEDFORD  83112
# 29467  5c8eccc1caa187d17ca76048      DANIEL  83115
# 29468  5c8eccc1caa187d17ca7604c    LA BARGE  83123
# 29469  5c8eccc1caa187d17ca7604d      THAYNE  83127
#
#                                      loc    pop state   latitude   longitude
# 0       {'y': 33.414625, 'x': 86.999607}  39677    AL  33.414625   86.999607
# 1       {'y': 33.434277, 'x': 87.167455}   3205    AL  33.434277   87.167455
# 2       {'y': 34.082117, 'x': 87.048395}   2270    AL  34.082117   87.048395
# 3       {'y': 33.176964, 'x': 86.616145}   4486    AL  33.176964   86.616145
# 4        {'y': 33.63356, 'x': 86.948221}   4429    AL  33.633560   86.948221
# ...                                  ...    ...   ...        ...         ...
# 29465  {'y': 43.771201, 'x': 110.857493}    519    WY  43.771201  110.857493
# 29466   {'y': 42.932336, 'x': 110.95556}   1177    WY  42.932336  110.955560
# 29467  {'y': 42.917629, 'x': 110.133624}    398    WY  42.917629  110.133624
# 29468   {'y': 42.24734, 'x': 110.210865}    606    WY  42.247340  110.210865
# 29469  {'y': 42.933026, 'x': 111.011354}    505    WY  42.933026  111.011354
#
# [29470 rows x 8 columns]

# %%
df=df_merged.drop(columns=['loc'])
df
# Out:
#                             _id        city    zip    pop state   latitude  \
# 0      5c8eccc1caa187d17ca6ed1a    HUEYTOWN  35023  39677    AL  33.414625
# 1      5c8eccc1caa187d17ca6ed1e       ADGER  35006   3205    AL  33.434277
# 2      5c8eccc1caa187d17ca6ed2a  CRANE HILL  35053   2270    AL  34.082117
# 3      5c8eccc1caa187d17ca6ed2d  COLUMBIANA  35051   4486    AL  33.176964
# 4      5c8eccc1caa187d17ca6ed32       ALDEN  35073   4429    AL  33.633560
# ...                         ...         ...    ...    ...   ...        ...
# 29465  5c8eccc1caa187d17ca7603e       MOOSE  83012    519    WY  43.771201
# 29466  5c8eccc1caa187d17ca76043     BEDFORD  83112   1177    WY  42.932336
# 29467  5c8eccc1caa187d17ca76048      DANIEL  83115    398    WY  42.917629
# 29468  5c8eccc1caa187d17ca7604c    LA BARGE  83123    606    WY  42.247340
# 29469  5c8eccc1caa187d17ca7604d      THAYNE  83127    505    WY  42.933026
#
#         longitude
# 0       86.999607
# 1       87.167455
# 2       87.048395
# 3       86.616145
# 4       86.948221
# ...           ...
# 29465  110.857493
# 29466  110.955560
# 29467  110.133624
# 29468  110.210865
# 29469  111.011354
#
# [29470 rows x 7 columns]
